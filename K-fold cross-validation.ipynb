# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# %%
k_range = list(np.linspace(50, 200, 5).astype('int'))
k_scores = []

for k in k_range:
    another_model = RandomForestRegressor(n_estimators = k, n_jobs = 7)
    scores = cross_val_score(another_model, X, y, cv = 10)
    k_scores.append(scores.mean())
    
print(k_scores)
# Out:
# [0.7820413216856613, 0.7843543788252101, 0.7855195053121097, 0.7867649042937378, 0.7868806521283218]

# %%
plt.plot(k_range, k_scores)
plt.xlabel('Value for estimators in k.')
plt.ylabel('Cross-validation mse')
plt.show()
